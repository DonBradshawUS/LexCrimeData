# %% [markdown]
# Import pandas, numpy, matplotlib, and seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read in the first csv and display the data.

# %%
df1 = pd.read_csv('data/2023_property_crime.csv',
    header=0,
    index_col=['crime_type', 'total_type'],
    usecols=['crime_type', 'total_type'])
display(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(breaking_entering, 1112), (theft, 7118), (auto_theft, 1308), (arson, 21)]

# %% [markdown]
# Graph the results from the first set of data.

# %%
x = np.array(["Breaking & Entering", "Theft", "Auto Theft", "Arson"])
y = np.array([1112, 7118, 1308, 21])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2023 Property Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Read in the second csv and display the data.

# %%
df2 = pd.read_csv('data/2023_violent_crime.csv',
    header=0,
    index_col=['crime_type', 'total_type'],
    usecols=['crime_type', 'total_type'])
display(df2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(murder, 24), (rape, 157), (robbery, 252), (aggravated_assault, 382)]

# %% [markdown]
# Graph the results of the second set of data.

# %%
x = np.array(["Murder", "Rape", "Robbery", "Aggravated Assault"])
y = np.array([24, 157, 252, 382])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2023 Violent Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Join the first and second sets of data to compare total types.

# %%
df3 = df1.join(df2, how='outer')
display(df3)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(aggravated_assault, 382), (arson, 21), (auto_theft, 1308), (breaking_entering, 1112), (murder, 24), (rape, 157), (robbery, 252), (theft, 7118)]

# %% [markdown]
# Graph the joined data sets to compare the crime types.

# %%
x = np.array(["Assault", "Arson", "Auto Theft", "B & E", "Murder", "Rape", "Robbery", "Theft"])
y = np.array([382, 21, 1308, 1112, 24, 157, 252, 7118])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2023 Total Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Read in the third csv and display the data.

# %%
df4 = pd.read_csv('data/2022_property_crime.csv',
    header=0,
    index_col=['crime_type', 'total_type'],
    usecols=['crime_type', 'total_type'])
display(df4)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(breaking_entering, 1141), (theft, 7109), (auto_theft, 1337), (arson, 22)]

# %% [markdown]
# Graph the results of the third set of data.

# %%
x = np.array(["Breaking & Entering", "Theft", "Auto Theft", "Arson"])
y = np.array([1141, 7109, 1337, 22])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2022 Property Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Read in the fourth csv and display the data.

# %%
df5 = pd.read_csv('data/2022_violent_crime.csv',
    header=0,
    index_col=['crime_type', 'total_type'],
    usecols=['crime_type', 'total_type'])
display(df5)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(murder, 44), (rape, 175), (robbery, 226), (aggravated_assault, 454)]

# %% [markdown]
# Graph the results of the fourth set of data.

# %%
x = np.array(["Murder", "Rape", "Robbery", "Aggravated Assault"])
y = np.array([44, 175, 226, 454])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2022 Violent Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Join the third and fourth sets of data to compare total types.

# %%
df6 = df4.join(df5, how='outer')
display(df6)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(aggravated_assault, 454), (arson, 22), (auto_theft, 1337), (breaking_entering, 1141), (murder, 44), (rape, 175), (robbery, 226), (theft, 7109)]

# %%
x = np.array(["Assault", "Arson", "Auto Theft", "B & E", "Murder", "Rape", "Robbery", "Theft"])
y = np.array([454, 22, 1337, 1141, 44, 175, 226, 7109])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("2022 Total Crime", fontdict = font1)
plt.xlabel("Crime Type", fontdict = font2)
plt.ylabel("Total Incidents", fontdict = font2)

plt.bar(x,y)
plt.show()

# %% [markdown]
# Plot the data from both years' totals.

# %%
ds1 = pd.DataFrame({'crime':["Assault", "Arson", "Auto Theft", "B & E", "Murder", "Rape", "Robbery", "Theft"],
                   'total': [382, 21, 1308, 1112, 24, 157, 252, 7118]})

ds2 = pd.DataFrame({'crime':["Assault", "Arson", "Auto Theft", "B & E", "Murder", "Rape", "Robbery", "Theft"],
                   'total': [454, 22, 1337, 1141, 44, 175, 226, 7109]})

ds1['year'] = '2023'
ds2['year'] = '2022'
dss = pd.concat([ds1, ds2])
sns.barplot(x='crime', y='total', hue='year', data=dss)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 10
#       8 ds2['ds'] = '2022'
#       9 dss = pd.concat([ds1, ds2])
# ---> 10 sns.barplot(x='crime', y='total', hue='year', data=dss)
#
# File c:\Users\donal\OneDrive\Documents\Code_You\LexCrimeData\.venv\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
# ...
